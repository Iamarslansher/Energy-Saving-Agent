# %% [markdown]
# <a href="https://colab.research.google.com/github/Iamarslansher/Energy-Saving-Agent/blob/main/arslansher_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata

api_key = userdata.get("agent-key")

client = genai.Client(api_key=api_key)

while True:
    user_input = input("You: ")

    if user_input.lower() in ["bye", "quit", "exit"]:
        print("AI: Goodbye! 👋")
        break

    response = client.interactions.create(
        model="gemini-3.8-flash",
        input=user_input
    )

    print("AI:", response.output_text)
# Out:
# AI: Hello! How can I help you today?
# You: exit
# AI: Goodbye! 👋
